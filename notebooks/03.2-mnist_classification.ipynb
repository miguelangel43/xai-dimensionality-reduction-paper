# %% [markdown]
# # Dimensionality Reduction and Classification on MNIST Dataset

# %%
import sys
sys.path.append('../src')
sys.path.append('../utils')
sys.path.append('../visualization')

import numpy as np
import pandas as pd
import pickle
import os

from dimensionality_reduction import apply_all_dimensionality_reduction
from classification import apply_classifiers_original_features, apply_classifiers_reduced_data

# Input
dataset_name = 'mnist'

# %%
# Read processed data
X_train = pickle.load(open(os.path.dirname(os.getcwd()) + f'/data/{dataset_name}/processed/X_train.pkl', 'rb'))
X_test = pickle.load(open(os.path.dirname(os.getcwd()) + f'/data/{dataset_name}/processed/X_test.pkl', 'rb'))
y_train = pickle.load(open(os.path.dirname(os.getcwd()) + f'/data/{dataset_name}/processed/y_train.pkl', 'rb'))
y_test = pickle.load(open(os.path.dirname(os.getcwd()) + f'/data/{dataset_name}/processed/y_test.pkl', 'rb'))

# %%
# Apply classifier on original data
apply_classifiers_original_features(X_train, y_train, X_test, y_test, 'mnist', classifiers=['XGBOOST', 'SVC', 'SGD'])
# Out:
# 0.85

# %%
# Reduce data
reduced_X = apply_all_dimensionality_reduction(X_train, X_test, y_train, 'mnist', n_components_list=[50, 100, 150],
                                               models_list=['SLMVP', 'PCA', 'KPCA', 'LOL', 'LLE'])
# Out:
# ('150Dim', 'LLE', 'k=24-reg=0.001'): 100%|██████████| 3/3 [00:06<00:00,  2.11s/it]
# Saved reduced data at path: /Users/espina/Unsynced/Whitepaper/data/mnist/reduced/reduced_X.pkl

# %%
# Read reduced data
reduced_X = pickle.load(open(os.path.dirname(os.getcwd()) + f'/data/{dataset_name}/reduced/reduced_X.pkl', 'rb'))

# %%
# Apply classifier on reduced data
scores_df, reduced_X_best = apply_classifiers_reduced_data(reduced_X, y_train, y_test, 'mnist',
                                                           classifiers=['XGBOOST', 'SVC', 'SGD'])
# Out:
# XGBoost: 100%|██████████| 18/18 [04:53<00:00, 16.33s/it]
# SVC: 100%|██████████| 18/18 [00:34<00:00,  1.93s/it]
# SGD: 100%|██████████| 18/18 [00:00<00:00, 19.40it/s]
# Scores saved at: /scores/mnist_scores.csv
# Reduced data saved at: /data/mnist/reduced/reduced_X_best.pkl

# %%
scores_df
# Out:
#       Model  Score                                             Params  \
# 23      SVC   0.90             {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 29      SVC   0.88             {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 35      SVC   0.87             {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 17  XGBoost   0.86                               {'n_estimators': 50}
# 53      SGD   0.85  {'alpha': 0.0001, 'average': False, 'class_wei...
# 47      SGD   0.84  {'alpha': 0.0001, 'average': False, 'class_wei...
# 11  XGBoost   0.84                              {'n_estimators': 100}
# 5   XGBoost   0.83                               {'n_estimators': 20}
# 4   XGBoost   0.83                               {'n_estimators': 50}
# 41      SGD   0.82  {'alpha': 0.0001, 'average': False, 'class_wei...
# 2   XGBoost   0.80                              {'n_estimators': 100}
# 16  XGBoost   0.79                               {'n_estimators': 50}
# 8   XGBoost   0.78                               {'n_estimators': 50}
# 10  XGBoost   0.77                               {'n_estimators': 50}
# 40      SGD   0.74  {'alpha': 0.0001, 'average': False, 'class_wei...
# 14  XGBoost   0.73                              {'n_estimators': 100}
# 50      SGD   0.68  {'alpha': 0.0001, 'average': False, 'class_wei...
# 38      SGD   0.59  {'alpha': 0.0001, 'average': False, 'class_wei...
# 52      SGD   0.56  {'alpha': 0.0001, 'average': False, 'class_wei...
# 46      SGD   0.56  {'alpha': 0.0001, 'average': False, 'class_wei...
# 44      SGD   0.53  {'alpha': 0.0001, 'average': False, 'class_wei...
# 49      SGD   0.27  {'alpha': 0.0001, 'average': False, 'class_wei...
# 42      SGD   0.27  {'alpha': 0.0001, 'average': False, 'class_wei...
# 43      SGD   0.26  {'alpha': 0.0001, 'average': False, 'class_wei...
# 19      SVC   0.26          {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 36      SGD   0.24  {'alpha': 0.0001, 'average': False, 'class_wei...
# 25      SVC   0.22             {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 37      SGD   0.21  {'alpha': 0.0001, 'average': False, 'class_wei...
# 26      SVC   0.20       {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 32      SVC   0.20       {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 18      SVC   0.20            {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 20      SVC   0.19        {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 13  XGBoost   0.18                               {'n_estimators': 20}
# 48      SGD   0.18  {'alpha': 0.0001, 'average': False, 'class_wei...
# 1   XGBoost   0.17                               {'n_estimators': 20}
# 24      SVC   0.17             {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 7   XGBoost   0.16                               {'n_estimators': 20}
# 0   XGBoost   0.15                               {'n_estimators': 50}
# 31      SVC   0.15             {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 39      SGD   0.14  {'alpha': 0.0001, 'average': False, 'class_wei...
# 21      SVC   0.14         {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 51      SGD   0.14  {'alpha': 0.0001, 'average': False, 'class_wei...
# 27      SVC   0.14         {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 12  XGBoost   0.13                               {'n_estimators': 50}
# 6   XGBoost   0.13                               {'n_estimators': 20}
# 30      SVC   0.12             {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 34      SVC   0.10            {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# 33      SVC   0.10              {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# 28      SVC   0.10            {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# 22      SVC   0.10            {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# 45      SGD   0.08  {'alpha': 0.0001, 'average': False, 'class_wei...
# 15  XGBoost   0.08                              {'n_estimators': 100}
# 9   XGBoost   0.08                                {'n_estimators': 5}
# 3   XGBoost   0.08                               {'n_estimators': 20}
#
#    Dimensions Dim. Technique         Dim. Params
# 23      50Dim            LLE      k=24-reg=0.001
# 29     100Dim            LLE      k=24-reg=0.001
# 35     150Dim            LLE      k=24-reg=0.001
# 17     150Dim            LLE      k=24-reg=0.001
# 53     150Dim            LLE      k=24-reg=0.001
# 47     100Dim            LLE      k=24-reg=0.001
# 11     100Dim            LLE      k=24-reg=0.001
# 5       50Dim            LLE      k=24-reg=0.001
# 4       50Dim            LOL
# 41      50Dim            LLE      k=24-reg=0.001
# 2       50Dim            PCA
# 16     150Dim            LOL
# 8      100Dim            PCA
# 10     100Dim            LOL
# 40      50Dim            LOL
# 14     150Dim            PCA
# 50     150Dim            PCA
# 38      50Dim            PCA
# 52     150Dim            LOL
# 46     100Dim            LOL
# 44     100Dim            PCA
# 49     150Dim          SLMVP   Radial-Gammas=0.1
# 42     100Dim          SLMVP  Radial-Gammas=0.01
# 43     100Dim          SLMVP   Radial-Gammas=0.1
# 19      50Dim          SLMVP   Radial-Gammas=0.1
# 36      50Dim          SLMVP  Radial-Gammas=0.01
# 25     100Dim          SLMVP   Radial-Gammas=0.1
# 37      50Dim          SLMVP   Radial-Gammas=0.1
# 26     100Dim            PCA
# 32     150Dim            PCA
# 18      50Dim          SLMVP  Radial-Gammas=0.01
# 20      50Dim            PCA
# 13     150Dim          SLMVP   Radial-Gammas=0.1
# 48     150Dim          SLMVP  Radial-Gammas=0.01
# 1       50Dim          SLMVP   Radial-Gammas=0.1
# 24     100Dim          SLMVP  Radial-Gammas=0.01
# 7      100Dim          SLMVP   Radial-Gammas=0.1
# 0       50Dim          SLMVP  Radial-Gammas=0.01
# 31     150Dim          SLMVP   Radial-Gammas=0.1
# 39      50Dim           KPCA              Radial
# 21      50Dim           KPCA              Radial
# 51     150Dim           KPCA              Radial
# 27     100Dim           KPCA              Radial
# 12     150Dim          SLMVP  Radial-Gammas=0.01
# 6      100Dim          SLMVP  Radial-Gammas=0.01
# 30     150Dim          SLMVP  Radial-Gammas=0.01
# 34     150Dim            LOL
# 33     150Dim           KPCA              Radial
# 28     100Dim            LOL
# 22      50Dim            LOL
# 45     100Dim           KPCA              Radial
# 15     150Dim           KPCA              Radial
# 9      100Dim           KPCA              Radial
# 3       50Dim           KPCA              Radial
