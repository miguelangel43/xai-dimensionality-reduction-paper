# %% [markdown]
# # Dimensionality Reduction and Classification on MNIST Dataset

# %%
import sys
sys.path.append('../src')
sys.path.append('../utils')
sys.path.append('../visualization')

import numpy as np
import pandas as pd
import pickle
import os

from dimensionality_reduction import apply_all_dimensionality_reduction
from classification import apply_classifiers_original_features, apply_classifiers_reduced_data

# %%
# Read processed data
X_train = pickle.load(open(os.path.dirname(os.getcwd()) + '/data/mnist/processed/X_train.pkl', 'rb'))
X_test = pickle.load(open(os.path.dirname(os.getcwd()) + '/data/mnist/processed/X_test.pkl', 'rb'))
y_train = pickle.load(open(os.path.dirname(os.getcwd()) + '/data/mnist/processed/y_train.pkl', 'rb'))
y_test = pickle.load(open(os.path.dirname(os.getcwd()) + '/data/mnist/processed/y_test.pkl', 'rb'))

# Flatten the images
X_train = np.array(X_train).reshape((len(X_train), -1))
X_test = np.array(X_test).reshape((len(X_test), -1))

# %%
from sklearn.linear_model import SGDClassifier

model = SGDClassifier(random_state=42)
model.fit(X_train, y_train)

# %%
# Apply classifier on original data
apply_classifiers_original_features(X_train, y_train, X_test, y_test, 'mnist', classifiers=['SVC'])

# %%
# Reduce data
reduced_X = apply_all_dimensionality_reduction(X_train, X_test, y_train, 'mnist', n_components_list=[5, 15, 50, 150],
                                               models_list=['SLMVP', 'PCA', 'KPCA', 'LOL', 'LLE'])
# Out:
# ('5Dim', 'SLMVP', 'Radial-Gammas=0.01'):   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# Apply classifier on reduced data
scores_df, reduced_X_best = apply_classifiers_reduced_data(reduced_X, y_train, y_test, 'mnist', classifiers=['SVC'])
# Out:
# SVC: 100%|██████████| 24/24 [00:15<00:00,  1.54it/s]

# %%
scores_df
# Out:
#    Model    Score                                        Params Dimensions  \
# 23   SVC  0.97500     {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}     150Dim
# 17   SVC  0.93125        {'C': 10, 'gamma': 1, 'kernel': 'rbf'}      50Dim
# 14   SVC  0.86875  {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}      50Dim
# 20   SVC  0.85625  {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}     150Dim
# 11   SVC  0.80625       {'C': 100, 'gamma': 1, 'kernel': 'rbf'}      15Dim
# 5    SVC  0.73125      {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}       5Dim
# 2    SVC  0.67500   {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}       5Dim
# 8    SVC  0.60625  {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}      15Dim
# 22   SVC  0.02500       {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}     150Dim
# 21   SVC  0.02500        {'C': 10, 'gamma': 1, 'kernel': 'rbf'}     150Dim
# 19   SVC  0.02500        {'C': 10, 'gamma': 1, 'kernel': 'rbf'}     150Dim
# 18   SVC  0.02500        {'C': 10, 'gamma': 1, 'kernel': 'rbf'}     150Dim
# 16   SVC  0.02500       {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}      50Dim
# 15   SVC  0.02500       {'C': 100, 'gamma': 1, 'kernel': 'rbf'}      50Dim
# 0    SVC  0.02500       {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}       5Dim
# 13   SVC  0.02500       {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}      50Dim
# 1    SVC  0.02500       {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}       5Dim
# 10   SVC  0.02500       {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}      15Dim
# 9    SVC  0.02500      {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}      15Dim
# 7    SVC  0.02500       {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}      15Dim
# 6    SVC  0.02500       {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}      15Dim
# 4    SVC  0.02500       {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}       5Dim
# 3    SVC  0.02500        {'C': 10, 'gamma': 1, 'kernel': 'rbf'}       5Dim
# 12   SVC  0.02500        {'C': 10, 'gamma': 1, 'kernel': 'rbf'}      50Dim
#
#    Dim. Technique         Dim. Params
# 23            LLE      k=15-reg=0.001
# 17            LLE      k=15-reg=0.001
# 14            PCA
# 20            PCA
# 11            LLE      k=15-reg=0.001
# 5             LLE      k=15-reg=0.001
# 2             PCA
# 8             PCA
# 22            LOL
# 21           KPCA              Radial
# 19          SLMVP   Radial-Gammas=0.1
# 18          SLMVP  Radial-Gammas=0.01
# 16            LOL
# 15           KPCA              Radial
# 0           SLMVP  Radial-Gammas=0.01
# 13          SLMVP   Radial-Gammas=0.1
# 1           SLMVP   Radial-Gammas=0.1
# 10            LOL
# 9            KPCA              Radial
# 7           SLMVP   Radial-Gammas=0.1
# 6           SLMVP  Radial-Gammas=0.01
# 4             LOL
# 3            KPCA              Radial
# 12          SLMVP  Radial-Gammas=0.01
